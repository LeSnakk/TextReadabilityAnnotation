# %% [markdown]
# # Reading CSV database
#
# **1. Set `runtime type` to `GPU`.**

# %%
# !git clone https://github.com/LeSnakk/TextReadabilityAnnotation
# Out:
# Cloning into 'TextReadabilityAnnotation'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 68 (delta 15), reused 54 (delta 10), pack-reused 0
# Receiving objects: 100% (68/68), 16.18 MiB | 28.97 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
import pandas as pd

# %%
database_path = '/kaggle/working/TextReadabilityAnnotation/project-files/annotation-data-text/text-preprocessed/CLEAR_Corpus_6.01_shortened.csv'
output_path = '/kaggle/working/TextReadabilityAnnotation/project-files/llm-data/llm-results/CLEAR_Corpus_6.01_LLM-output.csv'

# %%
import shutil
shutil.copyfile(database_path, output_path)

# %%
# Extract excerpts from database
data = pd.read_csv(output_path)

excerpts = data['Excerpt'].tolist()

excerpts = [excerpt.replace('\n', ' ') for excerpt in excerpts]

print(f'Loaded database with {len(excerpts)} excerpts.')
# Out:
# Loaded database with 4724 excerpts.

# %% [markdown]
# # Setting up LLAMA model

# %%
# !pip install transformers torch accelerate
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.36.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.25.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# Input HuggingFace token
# Make sure access to Llama 2 is granted
print('Please input your HuggingFace token:')
token = input()

# !huggingface-cli login --token {token}

print('Logged in as:')
# !huggingface-cli whoami

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf" # meta-llama/Llama-2-7b-hf
# model = "meta-llama/Llama-2-13b-chat-hf" # meta-llama/Llama-2-13b-hf

tokenizer = AutoTokenizer.from_pretrained(model, use_auth_token=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:690: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
from transformers import pipeline

llama_pipeline = pipeline(
    "text-generation",  # LLM task
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
def get_llama_response(prompt: str) -> None:

    sequences = llama_pipeline(
        prompt,
        do_sample=True,
        top_k=40,
        top_p=0.1,
        temperature=0.7,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        max_length=512,
    )
    generated_text = sequences[0]['generated_text']
    prompt_length = len(prompt)
    cleaned_text = generated_text[prompt_length:].strip()
    # print("Chatbot:", sequences[0]['generated_text'])
    return cleaned_text

# %%
prompt = 'To which model am I talking to?'
print(get_llama_response(prompt))
# Out:
# Answer: You are talking to the BERT model. BERT (Bidirectional Encoder Representations from Transformers) is a language model developed by Google in 2018. It is a pre-trained deep learning model that can be fine-tuned for a wide range of natural language processing (NLP) tasks, such as sentiment analysis, question-answering, and text classification. BERT is particularly useful for tasks that require a deep understanding of the nuances of language, such as language translation, summarization, and generation.

# %% [markdown]
# # Tasking the model

# %%
prompt = f'What is the following text about: "{excerpts[8]}"?'
print(get_llama_response(prompt))

# %%
prompt = f'Can you give me a readability score between 0, meaning hard to read, and 1, meaning easy to read "{excerpts[7]}"?'
print(get_llama_response(prompt))

# %%
prompt = f'How would you rate the readability of the following text on a scale from 1, which means hard, to 10, which means easy "{excerpts[7]}"? Your answer should look like this "Score", following the score, and "Explanation", why you rated it like this.'
print(get_llama_response(prompt))

# %%
for i in range(11):
  prompt = f'How would you rate the readability of the following text on a scale from 0, which means hard, to 100, which means easy "{excerpts[i]}"? Your answer should look like this "Score", following the score, and "Explanation", why you rated it like this.'
  print(f'Text {i}:')
  print(get_llama_response(prompt))

# %%
# Test model
for i in range(11):
  prompt = f'How would you rate the readability in percent of the following text 0% means hard to read, 100% means easy to read "{excerpts[i]}"? Your answer should look like this "Score", following the score, and "Explanation", why you rated it like this.'
  print(f'Text {i}:')
  response = get_llama_response(prompt)
  print(response)
  try:
    split_output = response.split('\n')
    if len(split_output) >= 2 and split_output[0].startswith("Score:") and split_output[1].startswith("Explanation:"):
        score_with_percentage = split_output[0].split(': ')[1]
        score = score_with_percentage.replace('%', '')
        explanation = split_output[1].split(': ')[1]
        print('SCORE: ', score)
        print('EXPLANATION: ', explanation)
    else:
        print("Output format not recognized.")
  except Exception as e:
    print("An error occurred:", str(e))
# Out:
# Text 0:
# Score: 60%
# Explanation: The text is written in a descriptive style, with vivid imagery and figurative language, which makes it easy to visualize the winter landscape. The use of words like "rumpled," "powdered," and "glittering" adds to the readability of the text. However, there are some complex sentences and long phrases that may make it difficult for some readers to follow. Overall, the text is moderately easy to read, with a readability score of around 60%.
# SCORE:  60
# EXPLANATION:  The text is written in a descriptive style, with vivid imagery and figurative language, which makes it easy to visualize the winter landscape. The use of words like "rumpled," "powdered," and "glittering" adds to the readability of the text. However, there are some complex sentences and long phrases that may make it difficult for some readers to follow. Overall, the text is moderately easy to read, with a readability score of around 60%.
# Text 1:
# For example: "Score: 60%, Explanation: The text is written in a clear and concise manner, with simple vocabulary and short sentences. However, the language is somewhat formal and lacks colloquialisms, making it slightly harder to read."
# Unexpected output format. Unable to extract score and explanation.
# Text 2:
# 0% - Hard to read, 100% - Easy to read.
# Unexpected output format. Unable to extract score and explanation.
# Text 3:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a mix of complex and simple sentences. The use of vocabulary such as "chimney-sweep," "prison," and "flag of truce" may challenge some readers, but the overall structure of the text is relatively straightforward.
#
# Score: 80%
# Explanation: The text has a relatively high level of readability, with a good balance of complex and simple sentences. The author uses a range of vocabulary and sentence structures to convey the story, making it easier for readers to follow. However, some of the sentences are quite long, which may make them difficult for some readers to comprehend.
#
# Score: 90%
# Explanation: The text has a very high level of readability, with most sentences being relatively short and straightforward. The author uses simple vocabulary and sentence structures to convey the story, making it easy for readers to follow. The text is well-organized and easy to understand, with a
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a mix of complex and simple sentences. The use of vocabulary such as "chimney-sweep," "prison," and "flag of truce" may challenge some readers, but the overall structure of the text is relatively straightforward.
# Text 4:
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Answer:
#
# Score: 70%
# Explanation: The text has a moderate level of readability, with a mix of complex and simple sentences. The use of compound sentences and adjectives like "stiff with gold" and "sculptured goblet" create some difficulty, but the overall structure is clear and easy to follow. The text also uses repetition, with the phrase "the heavens had given" appearing twice, which can make it feel more readable. However, some of the vocabulary, such as "walled round" and "pledged the merchant kings," may be unfamiliar to some readers, which could affect readability.
# Unexpected output format. Unable to extract score and explanation.
# Text 5:
# Answer:
# Score: 80%
# Explanation: The text is written in a simple and clear manner, with short sentences and basic vocabulary. It is easy to follow the story and understand the characters and their belongings. However, some of the sentences are a bit long and could be broken up for better readability. Overall, the text is easy to read but could benefit from some minor adjustments for improved readability.
# Unexpected output format. Unable to extract score and explanation.
# Text 6:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read.". Please answer with a score and an explanation for each text you read.
# Unexpected output format. Unable to extract score and explanation.
# Text 7:
# Score: 80%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. The story is easy to follow, and the use of proper nouns (such as "Hal Paine," "Chester Crawford," "Major Raoul Derevaux," and "Captain Harry Anderson") helps to establish the characters and their roles in the story. However, some of the sentences are quite long, which can make them difficult to follow for some readers. Overall, the readability of the text is around 80%.
# SCORE:  80
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. The story is easy to follow, and the use of proper nouns (such as "Hal Paine," "Chester Crawford," "Major Raoul Derevaux," and "Captain Harry Anderson") helps to establish the characters and their roles in the story. However, some of the sentences are quite long, which can make them difficult to follow for some readers. Overall, the readability of the text is around 80%.
# Text 8:
# Score: 60%
# Explanation: The text is written in a formal and structured manner, with a clear and concise sentence structure. However, the vocabulary and sentence length are somewhat complex, making it challenging for some readers to follow. The use of technical terms like "automobile," "battle line," and "armies" may also pose a challenge for some readers. Overall, the readability of the text is around 60%.
# SCORE:  60
# EXPLANATION:  The text is written in a formal and structured manner, with a clear and concise sentence structure. However, the vocabulary and sentence length are somewhat complex, making it challenging for some readers to follow. The use of technical terms like "automobile," "battle line," and "armies" may also pose a challenge for some readers. Overall, the readability of the text is around 60%.
# Text 9:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Unexpected output format. Unable to extract score and explanation.
# Text 10:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       2 prompt = f'How would you rate the readability in percent of the following text 0% means hard to read, 100% means easy to read "{excerpts[i]}"? Your answer should look like this "Score", following the score, and "Explanation", why you rated it like this.'
#       3 print(f'Text {i}:')
# ----> 4 response = get_llama_response(prompt)
#       5 print(response)
#       6 try:
#
# Cell In[12], line 3, in get_llama_response(prompt)
#       1 def get_llama_response(prompt: str) -> None:
# ----> 3     sequences = llama_pipeline(
#       4         prompt,
#       5         do_sample=True,
#       6         top_k=40,
#       7         top_p=0.1,
#       8         temperature=0.7,
#       9         num_return_sequences=1,
#      10         eos_token_id=tokenizer.eos_token_id,
#      11         max_length=512,
#      12     )
#      13     generated_text = sequences[0]['generated_text']
#      14     prompt_length = len(prompt)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:208, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     167 def __call__(self, text_inputs, **kwargs):
#     168     """
#     169     Complete the prompt(s) given as inputs.
#     170
#    (...)
#     206           ids of the generated text.
#     207     """
# --> 208     return super().__call__(text_inputs, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1140, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1132     return next(
#    1133         iter(
#    1134             self.get_iterator(
#    (...)
#    1137         )
#    1138     )
#    1139 else:
# -> 1140     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1147, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1145 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1146     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1147     model_outputs = self.forward(model_inputs, **forward_params)
#    1148     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1149     return outputs
#
# File /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1046, in Pipeline.forward(self, model_inputs, **forward_params)
#    1044     with inference_context():
#    1045         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1046         model_outputs = self._forward(model_inputs, **forward_params)
#    1047         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1048 else:
#
# File /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:271, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     268         generate_kwargs["min_length"] += prefix_length
#     270 # BS x SL
# --> 271 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     272 out_b = generated_sequence.shape[0]
#     273 if self.framework == "pt":
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1764, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1756     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1757         input_ids=input_ids,
#    1758         expand_size=generation_config.num_return_sequences,
#    1759         is_encoder_decoder=self.config.is_encoder_decoder,
#    1760         **model_kwargs,
#    1761     )
#    1763     # 13. run sample
# -> 1764     return self.sample(
#    1765         input_ids,
#    1766         logits_processor=logits_processor,
#    1767         logits_warper=logits_warper,
#    1768         stopping_criteria=stopping_criteria,
#    1769         pad_token_id=generation_config.pad_token_id,
#    1770         eos_token_id=generation_config.eos_token_id,
#    1771         output_scores=generation_config.output_scores,
#    1772         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1773         synced_gpus=synced_gpus,
#    1774         streamer=streamer,
#    1775         **model_kwargs,
#    1776     )
#    1778 elif generation_mode == GenerationMode.BEAM_SEARCH:
#    1779     # 11. prepare beam search scorer
#    1780     beam_scorer = BeamSearchScorer(
#    1781         batch_size=batch_size,
#    1782         num_beams=generation_config.num_beams,
#    (...)
#    1787         max_length=generation_config.max_length,
#    1788     )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:2897, in GenerationMixin.sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2895 # sample
#    2896 probs = nn.functional.softmax(next_token_scores, dim=-1)
# -> 2897 next_tokens = torch.multinomial(probs, num_samples=1).squeeze(1)
#    2899 # finished sentences should have their next token be a padding token
#    2900 if eos_token_id is not None:
#
# KeyboardInterrupt:

# %%
# Add LLM columns to CSV data
new_column = {'LLAMA Score': '', 'LLAMA Explanation': ''}

data = pd.read_csv(output_path)

data['LLAMA Score'] = new_column['LLAMA Score']
data['LLAMA Explanation'] = new_column['LLAMA Explanation']

data.to_csv(output_path, index=False)

# %%
# Retrieve LLM score and explanation and add them to CSV data
for i in range(0, min(5000, len(excerpts))):    
  prompt = f'How would you rate the readability in percent of the following text 0% means hard to read, 100% means easy to read "{excerpts[i]}"? Your answer should look like this "Score", following the score, and "Explanation", why you rated it like this.'
  print(f'Text {i}:')
  response = get_llama_response(prompt)
  print(response)
  try:
    split_output = response.split('\n')
    if len(split_output) >= 2 and split_output[0].startswith("Score:") and split_output[1].startswith("Explanation:"):
        score_with_percentage = split_output[0].split(': ')[1]
        score = score_with_percentage.replace('%', '')
        explanation = split_output[1].split(': ')[1]
        print('SCORE: ', score)
        data.at[i, 'LLAMA Score'] = score
        print('EXPLANATION: ', explanation)
        data.at[i, 'LLAMA Explanation'] = explanation
        data.to_csv(output_path, index=False)
    else:
        print("Output format not recognized.")
        data.at[i, 'LLAMA Explanation'] = response
        data.to_csv(output_path, index=False)
  except Exception as e:
    print("An error occurred:", str(e))
    print(f'Text {i}:')
# Out:
# Text 4000:
# For example, "Score: 80%, Explanation: The text is written in clear and concise language, with short sentences and simple vocabulary, making it easy to read.". Please answer with a score and an explanation for each text you rate.
# Output format not recognized.
# Text 4001:
# 0% - 20% = Very Hard to Read, 21% - 40% = Hard to Read, 41% - 60% = Somewhat Difficult, 61% - 80% = Easy to Read, 81% - 100% = Very Easy to Read.
# Output format not recognized.
# Text 4002:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with simple vocabulary and sentence structure, making it easy to read."
# Output format not recognized.
# Text 4003:
# For example, "Score: 70%, Explanation: The text uses complex vocabulary and sentence structures, making it difficult to read for a beginner.".
# Output format not recognized.
# Text 4004:
# Answer:
# Score: 70%
# Explanation: The text has a moderate level of readability, with a mix of simple and complex vocabulary, and a clear but somewhat descriptive sentence structure. The use of phrases like "Every morning he was up at sunrise" and "learned to ride a horse" make the text easier to read, while the longer sentences with more complex vocabulary, such as "Ivar taught him to play the harp and to make up songs" and "When the men in the smithy saw the runes they opened their eyes wide and looked at the boy", require more effort to comprehend. Overall, the text is easy to read but may challenge some readers, especially those with limited exposure to Norse language and culture.
# Output format not recognized.
# Text 4005:
# Score: 80%
# Explanation: This text is relatively easy to read, with a moderate level of complexity. The vocabulary is varied, but most words are familiar to a high school reader. The sentence structure is clear and straightforward, with a mix of short and longer sentences. However, some of the sentences are quite long, which can make them difficult to follow. Additionally, there are a few technical terms (e.g. "sorority," "Greek letter society") that may be unfamiliar to some readers. Overall, the text is well-written and easy to follow, but it may pose some challenges for struggling readers.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a moderate level of complexity. The vocabulary is varied, but most words are familiar to a high school reader. The sentence structure is clear and straightforward, with a mix of short and longer sentences. However, some of the sentences are quite long, which can make them difficult to follow. Additionally, there are a few technical terms (e.g. "sorority," "Greek letter society") that may be unfamiliar to some readers. Overall, the text is well-written and easy to follow, but it may pose some challenges for struggling readers.
# /tmp/ipykernel_42/2434353725.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '80' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.at[i, 'LLAMA Score'] = score
# Text 4006:
# For example:
#
# Score: 60%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, it may be challenging for some readers to follow the narrative due to the lack of context and character development.
#
# Please provide your answer in the format above.
# Output format not recognized.
# Text 4007:
# 0% - Very hard to read, 10% - Hard to read, 20% - Somewhat difficult, 30% - Neutral, 40% - Somewhat easy, 50% - Easy to read, 60% - Very easy to read, 70% - Extremely easy to read, 80% - Nearly effortless to read, 90% - Extremely easy to read, 100% - Nearly effortless to read.
# Output format not recognized.
# Text 4008:
# For example:
#
# Score: 80%
# Explanation: This text is relatively easy to read, with a moderate level of complexity. The language is sophisticated, but the sentences are well-structured and easy to follow. The use of figurative language, such as "purest realization" and "radiant glory," adds depth and interest to the text without making it overly difficult to understand. However, some of the sentences are quite long and could be broken up for easier reading. Overall, the text is accessible to a wide range of readers, but may pose some challenges for those with limited English proficiency or for readers who are not used to reading complex texts.
# Output format not recognized.
# Text 4009:
# For example, "Score: 70%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4010:
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# For example, "Score: 60%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4011:
# Score: 80%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. The use of concrete nouns and verbs helps to create a vivid image of the scene, making it easy to visualize. However, some of the sentences are quite long and could be broken up for easier reading. Overall, the readability is high, but not perfect.
# SCORE:  80
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. The use of concrete nouns and verbs helps to create a vivid image of the scene, making it easy to visualize. However, some of the sentences are quite long and could be broken up for easier reading. Overall, the readability is high, but not perfect.
# Text 4012:
# For example:
#
# Score: 60%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, it is not overly engaging or interesting, which is why I would rate it at 60% readability.
#
# Please provide your answer for the given text.
# Output format not recognized.
# Text 4013:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a vocabulary that is slightly above average and sentence structures that are generally clear and straightforward. However, there are some complex sentences and clauses that may make it difficult for some readers to follow, particularly those with lower reading levels. Additionally, some of the vocabulary may be unfamiliar to younger readers, such as "punishment," "forbidden," and "avowing." Overall, the text is likely to be challenging for readers with lower reading levels, but still accessible to those with higher levels of proficiency.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a vocabulary that is slightly above average and sentence structures that are generally clear and straightforward. However, there are some complex sentences and clauses that may make it difficult for some readers to follow, particularly those with lower reading levels. Additionally, some of the vocabulary may be unfamiliar to younger readers, such as "punishment," "forbidden," and "avowing." Overall, the text is likely to be challenging for readers with lower reading levels, but still accessible to those with higher levels of proficiency.
# Text 4014:
# For example, "Score: 80%, Explanation: The text is written in a descriptive style with vivid imagery, making it easy to visualize the characters and their surroundings."
# Output format not recognized.
# Text 4015:
# 0% - Very Hard to Read, 100% - Very Easy to Read.
# Output format not recognized.
# Text 4016:
# Score: 60%
# Explanation: The text is written in a formal, old-fashioned style, with long sentences and complex vocabulary. It also contains some difficult vocabulary and sentence structures, which may make it challenging for some readers to follow. However, the text does contain some repetition and rhythm, which can help with comprehension. Overall, the readability of the text is around 60%.
# SCORE:  60
# EXPLANATION:  The text is written in a formal, old-fashioned style, with long sentences and complex vocabulary. It also contains some difficult vocabulary and sentence structures, which may make it challenging for some readers to follow. However, the text does contain some repetition and rhythm, which can help with comprehension. Overall, the readability of the text is around 60%.
# Text 4017:
# Score: 60%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, it may be challenging for some readers, especially those who are not familiar with the dialect used in the text, to fully understand the meaning of each sentence. The use of words like "upthere" and "nobody" may also be difficult for some readers to comprehend. Overall, the readability of the text is around 60%.
# SCORE:  60
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, it may be challenging for some readers, especially those who are not familiar with the dialect used in the text, to fully understand the meaning of each sentence. The use of words like "upthere" and "nobody" may also be difficult for some readers to comprehend. Overall, the readability of the text is around 60%.
# Text 4018:
# For example:
#
# Score: 60%
# Explanation: The text is written in a clear and straightforward manner, with simple vocabulary and sentence structure. However, the subject matter is somewhat complex and may require some prior knowledge to fully understand.
#
# Please provide your answer in the format above.
# Output format not recognized.
# Text 4019:
# For example "Score: 80%, Explanation: The text is written in a clear and concise manner, with simple vocabulary and sentence structure, making it easy to read.".
# Output format not recognized.
# Text 4020:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read.".
# Output format not recognized.
# Text 4021:
# For example, "Score: 80%, Explanation: The text is written in a descriptive style with complex vocabulary and sentence structures, making it challenging to read for some readers."
# Output format not recognized.
# Text 4022:
# Score: 80%
# Explanation: This text is relatively easy to read, with a moderate level of complexity. The language used is straightforward and simple, with short sentences and basic vocabulary. However, there are some more advanced vocabulary words and phrases, such as "grandmother's trouble and work," "reckon," and "dreadful," which may challenge some readers. Overall, the text is well-structured and easy to follow, making it accessible to a wide range of readers.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a moderate level of complexity. The language used is straightforward and simple, with short sentences and basic vocabulary. However, there are some more advanced vocabulary words and phrases, such as "grandmother's trouble and work," "reckon," and "dreadful," which may challenge some readers. Overall, the text is well-structured and easy to follow, making it accessible to a wide range of readers.
# Text 4023:
# Score: 60%
# Explanation: This text has a moderate readability level, with an average sentence length of 13 words and a vocabulary size of 1,050 words. The language used is descriptive and imaginative, with vivid imagery and figurative language, which can make it more challenging to read for some readers. However, the text also includes some complex sentence structures and long sentences, which can make it harder to follow for some readers. Overall, the readability level of this text is around 60%.
# SCORE:  60
# EXPLANATION:  This text has a moderate readability level, with an average sentence length of 13 words and a vocabulary size of 1,050 words. The language used is descriptive and imaginative, with vivid imagery and figurative language, which can make it more challenging to read for some readers. However, the text also includes some complex sentence structures and long sentences, which can make it harder to follow for some readers. Overall, the readability level of this text is around 60%.
# Text 4024:
# Answer:
# Score: 70%
# Explanation: The text is written in a descriptive style with vivid imagery, which makes it easy to visualize the scene being described. The use of metaphors and similes, such as "friendly little star", "frightful thunder-bolts", and "black, frightful giant-forms", adds to the readability of the text. However, some of the sentences are quite long and complex, which may make it difficult for some readers to follow the flow of the text. Overall, the readability of the text is around 70%.
# Output format not recognized.
# Text 4025:
# For example, "Score: 60%, Explanation: The text is written in a descriptive style with vivid imagery, but the sentences are somewhat long and complex, making it difficult to follow for some readers."
# Output format not recognized.
# Text 4026:
# For example, "Score: 60%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read.".
# Output format not recognized.
# Text 4027:
# Score: 60%
# Explanation: The text has a moderate level of complexity, with long sentences and technical vocabulary. However, the meaning is clear and easy to follow, making it slightly easier to read than a text with a much higher level of complexity.
#
# Score: 80%
# Explanation: The text has a good level of readability, with short sentences and simple vocabulary. The meaning is clear and easy to follow, making it very easy to read.
#
# Score: 40%
# Explanation: The text has a high level of complexity, with long sentences and technical vocabulary. The meaning is not always clear, and some sentences may be difficult to follow, making it harder to read.
#
# Score: 20%
# Explanation: The text has an extremely high level of complexity, with very long sentences and highly technical vocabulary. The meaning is often obscure and difficult to follow, making it almost impossible to read without a lot of effort and background knowledge.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of complexity, with long sentences and technical vocabulary. However, the meaning is clear and easy to follow, making it slightly easier to read than a text with a much higher level of complexity.
# Text 4028:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read.".
# Output format not recognized.
# Text 4029:
# 0% - Very hard to read, 10% - Hard to read, 20% - Somewhat difficult, 30% - Average, 40% - Somewhat easy, 50% - Easy to read, 60% - Very easy to read, 70% - Extremely easy to read, 80% - Nearly perfect, 90% - Perfectly readable, 100% - Ideal for a wide range of readers.
# Output format not recognized.
# Text 4030:
# Score: 60%
# Explanation: This text has a moderate readability level, with a grade level of around 7-8. The language used is somewhat complex, with long sentences and a few challenging vocabulary words. However, the overall structure and organization of the text are clear and easy to follow, making it relatively accessible to readers.
#
# Score: 80%
# Explanation: This text has a relatively high readability level, with a grade level of around 9-10. The language used is mostly straightforward, with a few complex sentences and vocabulary words. The overall structure and organization of the text are clear and easy to follow, making it relatively easy for readers to understand.
#
# Score: 90%
# Explanation: This text has a very high readability level, with a grade level of around 11-12. The language used is mostly simple and straightforward, with only a few challenging vocabulary words.
# SCORE:  60
# EXPLANATION:  This text has a moderate readability level, with a grade level of around 7-8. The language used is somewhat complex, with long sentences and a few challenging vocabulary words. However, the overall structure and organization of the text are clear and easy to follow, making it relatively accessible to readers.
# Text 4031:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a mix of simple and complex sentences. The use of descriptive language, such as "palace," "feast," and "bright as the day," adds complexity, but the sentence structure is generally straightforward. However, some of the sentences are quite long, which can make them difficult to follow for some readers. Overall, the text is easy to read but may require some concentration to fully comprehend.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a mix of simple and complex sentences. The use of descriptive language, such as "palace," "feast," and "bright as the day," adds complexity, but the sentence structure is generally straightforward. However, some of the sentences are quite long, which can make them difficult to follow for some readers. Overall, the text is easy to read but may require some concentration to fully comprehend.
# Text 4032:
# Score: 70%
# Explanation: The text has a moderate level of readability, with a mix of simple and complex sentences. The story is easy to follow, but some of the vocabulary and sentence structures may be challenging for some readers.
#
# Score: 80%
# Explanation: The text has improved slightly in readability, with more simple sentences and a clearer structure. However, some of the language is still quite complex, and some readers may struggle with certain phrases or words.
#
# Score: 90%
# Explanation: The text has become much easier to read, with a high proportion of simple sentences and a clear, straightforward structure. The language is still varied and interesting, but it is now accessible to a wider range of readers.
# SCORE:  70
# EXPLANATION:  The text has a moderate level of readability, with a mix of simple and complex sentences. The story is easy to follow, but some of the vocabulary and sentence structures may be challenging for some readers.
# Text 4033:
# Score: 80%
# Explanation: This text has a relatively high readability score of 80% because it uses a mix of simple and complex vocabulary, with a good balance between short and long sentences. The language is descriptive and imaginative, with vivid imagery and sensory details that help to paint a picture of the scene. However, there are some longer sentences and more complex vocabulary that may make it slightly more challenging for some readers to follow. Overall, the text is well-written and enjoyable to read, but it may require a bit more effort to fully comprehend for some readers.
# SCORE:  80
# EXPLANATION:  This text has a relatively high readability score of 80% because it uses a mix of simple and complex vocabulary, with a good balance between short and long sentences. The language is descriptive and imaginative, with vivid imagery and sensory details that help to paint a picture of the scene. However, there are some longer sentences and more complex vocabulary that may make it slightly more challenging for some readers to follow. Overall, the text is well-written and enjoyable to read, but it may require a bit more effort to fully comprehend for some readers.
# Text 4034:
# Score: 80%
# Explanation: This text has a moderate level of readability. It contains a mix of simple and complex vocabulary, with some words that may be unfamiliar to younger readers. The sentence structure is generally clear and easy to follow, but there are a few long sentences that may cause difficulty for some readers. Overall, the text is still relatively easy to read, but it may require some effort for readers to fully comprehend the meaning of every sentence.
# SCORE:  80
# EXPLANATION:  This text has a moderate level of readability. It contains a mix of simple and complex vocabulary, with some words that may be unfamiliar to younger readers. The sentence structure is generally clear and easy to follow, but there are a few long sentences that may cause difficulty for some readers. Overall, the text is still relatively easy to read, but it may require some effort for readers to fully comprehend the meaning of every sentence.
# Text 4035:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4036:
# Score: 80%
# Explanation: This text has a relatively high readability score because it uses simple language and short sentences, making it easy to understand for a wide range of readers. The vocabulary is not too complex, and the sentences are straightforward and to the point. However, there are some poetic and figurative language elements, such as "I felt quite at home," "I was a green tree waving its branches in the wind," and "I fluttered my clumsy apologies for wings," which may make it slightly more challenging for some readers to follow. Overall, the text is well-written and easy to read, but it may require some concentration and attention to fully comprehend the meaning.
# SCORE:  80
# EXPLANATION:  This text has a relatively high readability score because it uses simple language and short sentences, making it easy to understand for a wide range of readers. The vocabulary is not too complex, and the sentences are straightforward and to the point. However, there are some poetic and figurative language elements, such as "I felt quite at home," "I was a green tree waving its branches in the wind," and "I fluttered my clumsy apologies for wings," which may make it slightly more challenging for some readers to follow. Overall, the text is well-written and easy to read, but it may require some concentration and attention to fully comprehend the meaning.
# Text 4037:
# Score: 80%
# Explanation: This text is relatively easy to read, with a moderate level of complexity. The language used is descriptive and vivid, with imaginative phrases like "comfortable white house," "spotless picket fence," and "hosts of green apples." The sentences are generally simple and straightforward, with a clear structure and rhythm. However, there are some more complex sentences, such as "The whole thing had been made as if to order; that is all there is to say about it," which may require a slightly higher level of comprehension. Overall, the text is well-written and engaging, but may pose some challenges for readers with lower levels of literacy or comprehension.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a moderate level of complexity. The language used is descriptive and vivid, with imaginative phrases like "comfortable white house," "spotless picket fence," and "hosts of green apples." The sentences are generally simple and straightforward, with a clear structure and rhythm. However, there are some more complex sentences, such as "The whole thing had been made as if to order; that is all there is to say about it," which may require a slightly higher level of comprehension. Overall, the text is well-written and engaging, but may pose some challenges for readers with lower levels of literacy or comprehension.
# Text 4038:
# For example, "Score: 80%, Explanation: The text is written in a descriptive style with vivid imagery, making it relatively easy to read."
# Output format not recognized.
# Text 4039:
# Score: 70%
# Explanation: This text has a moderate level of readability, with a few complex sentence structures and a range of vocabulary. The use of metaphor ("April day...unertain glory") and simile ("Irish rain...welcome") adds depth and interest to the text, but may challenge some readers. The repetition of certain words and phrases, such as "April," "Irish," and "beautiful," also contributes to the overall readability. However, the text is not overly difficult to read, and the use of descriptive language and imagery makes it engaging and enjoyable.
# SCORE:  70
# EXPLANATION:  This text has a moderate level of readability, with a few complex sentence structures and a range of vocabulary. The use of metaphor ("April day...unertain glory") and simile ("Irish rain...welcome") adds depth and interest to the text, but may challenge some readers. The repetition of certain words and phrases, such as "April," "Irish," and "beautiful," also contributes to the overall readability. However, the text is not overly difficult to read, and the use of descriptive language and imagery makes it engaging and enjoyable.
# Text 4040:
# 0% - Hard to read
# 10% - Some words are difficult to understand
# 20% - Some sentences are hard to follow
# 30% - Average readability
# 40% - Easy to read
# 50% - Very easy to read
# 60% - Extremely easy to read
# 70% - Nearly effortless to read
# 80% - Almost too easy to read
# 90% - Exceptionally easy to read
# 100% - Extraordinarily easy to read
#
# Please rate the readability of the given text.
# Output format not recognized.
# Text 4041:
# Score: 60%
# Explanation: This text has a moderate readability level, with a grade level of around 8-9. The language used is relatively complex, with long sentences and technical terms like "turquoise engagement ring" and "diamonds." The text also includes some figurative language, such as "disloyal thoughts" and "splendid being," which can make it more challenging to understand. However, the overall structure of the text is clear and easy to follow, which helps to make up for the more difficult language.
# SCORE:  60
# EXPLANATION:  This text has a moderate readability level, with a grade level of around 8-9. The language used is relatively complex, with long sentences and technical terms like "turquoise engagement ring" and "diamonds." The text also includes some figurative language, such as "disloyal thoughts" and "splendid being," which can make it more challenging to understand. However, the overall structure of the text is clear and easy to follow, which helps to make up for the more difficult language.
# Text 4042:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with simple vocabulary and short sentences, making it easy to read."
# Output format not recognized.
# Text 4043:
# For example:
#
# Score: 80%
# Explanation: The text has a moderate level of readability, with a few complex sentences and vocabulary words that may challenge some readers. However, the overall structure and flow of the text are clear and easy to follow, making it generally accessible to a wide range of readers.
#
# Please provide your answer in the format above.
# Output format not recognized.
# Text 4044:
# Score: 60%
# Explanation: The text is written in a formal, poetic style with complex sentence structures and vocabulary. It also uses metaphors and similes to describe the landscape, which can make it difficult to follow for some readers. However, the text is still relatively easy to read, with a high percentage of comprehensible words and a clear overall message.
#
# Score: 70%
# Explanation: The text is written in a more straightforward style than the previous example, with shorter sentences and simpler vocabulary. However, it still uses some poetic language and imagery, which can make it slightly harder to read for some readers. The overall message is clear, but some readers may struggle with the more complex language used to describe the landscape.
#
# Score: 80%
# Explanation: The text is written in a relatively straightforward style, with clear and concise sentences. The vocabulary is still somewhat complex, but it is generally easier to understand than the previous examples. The text
# SCORE:  60
# EXPLANATION:  The text is written in a formal, poetic style with complex sentence structures and vocabulary. It also uses metaphors and similes to describe the landscape, which can make it difficult to follow for some readers. However, the text is still relatively easy to read, with a high percentage of comprehensible words and a clear overall message.
# Text 4045:
# For example, "Score: 70%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4046:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a vocabulary that is not too complex but still requires some effort to understand. The sentences are relatively long and convoluted, which can make it harder to follow the meaning. However, the use of descriptive language and imagery helps to create a vivid picture of the scene, making it easier to visualize. Overall, the readability is around 60%.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a vocabulary that is not too complex but still requires some effort to understand. The sentences are relatively long and convoluted, which can make it harder to follow the meaning. However, the use of descriptive language and imagery helps to create a vivid picture of the scene, making it easier to visualize. Overall, the readability is around 60%.
# Text 4047:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a mix of complex and simple sentences. The use of vocabulary such as "dread fever," "undressing," and "pajamas" may challenge some readers, while the repetition of phrases like "too numerous to mention" and "get settled for the night" make the text more predictable and easier to read. Overall, the readability score is around 60%.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a mix of complex and simple sentences. The use of vocabulary such as "dread fever," "undressing," and "pajamas" may challenge some readers, while the repetition of phrases like "too numerous to mention" and "get settled for the night" make the text more predictable and easier to read. Overall, the readability score is around 60%.
# Text 4048:
# Score: 60%
# Explanation: This text has a moderate readability level, with an average sentence length of 13 words and a vocabulary size of 1,050 words. The language used is straightforward and easy to understand, but there are some complex sentences and vocabulary words that may challenge some readers.
#
# Score: 80%
# Explanation: This text has a relatively high readability level, with an average sentence length of 16 words and a vocabulary size of 1,300 words. The language used is clear and concise, with a good balance of simple and complex sentences. However, some of the vocabulary words may be unfamiliar to some readers.
#
# Score: 90%
# Explanation: This text has a very high readability level, with an average sentence length of 19 words and a vocabulary size of 1,500 words. The language used is mostly straightforward and easy to understand, with a few complex sentences and vocabulary words that may challenge some readers. Overall, this text is very easy
# SCORE:  60
# EXPLANATION:  This text has a moderate readability level, with an average sentence length of 13 words and a vocabulary size of 1,050 words. The language used is straightforward and easy to understand, but there are some complex sentences and vocabulary words that may challenge some readers.
# Text 4049:
# Score: 80%
# Explanation: The text is written in a descriptive style, using vivid imagery and sensory details to paint a picture of the scene. The language is complex, but not overly difficult to understand, making it an 80% readability score.
#
# Score: 70%
# Explanation: The text is written in a more straightforward style, with shorter sentences and simpler language. It is still a bit dense, but the meaning is clear and easy to follow, making it a 70% readability score.
#
# Score: 60%
# Explanation: The text is written in a simple, straightforward style, with short sentences and basic vocabulary. It is easy to understand, but the language is quite basic, making it a 60% readability score.
#
# Score: 50%
# Explanation: The text is written in a very simple style, with short sentences and basic vocabulary. It is easy to understand, but the language is quite basic and lacks the vivid imagery and sensory
# SCORE:  80
# EXPLANATION:  The text is written in a descriptive style, using vivid imagery and sensory details to paint a picture of the scene. The language is complex, but not overly difficult to understand, making it an 80% readability score.
# Text 4050:
# Score: 60%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, it may be challenging for some readers to follow the story due to the lack of context and character development. The use of descriptive language is effective in creating a visual image of the scene, but it may be difficult for some readers to fully immerse themselves in the story without more background information.
#
# Score: 80%
# Explanation: The text is generally easy to read, with short sentences and simple language. However, some of the sentences are quite long and complex, which may make them difficult for some readers to follow. Additionally, the use of figurative language, such as "fairyland" and "magic spell," may be challenging for some readers to understand without additional context.
#
# Score: 90%
# Explanation: The text is very easy to read, with short, simple sentences that are easy to follow
# SCORE:  60
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, it may be challenging for some readers to follow the story due to the lack of context and character development. The use of descriptive language is effective in creating a visual image of the scene, but it may be difficult for some readers to fully immerse themselves in the story without more background information.
# Text 4051:
# For example, "100%, easy to read" or "75%, moderately difficult to read".
# Output format not recognized.
# Text 4052:
# Score: 80%
# Explanation: This text has a relatively high readability score due to its use of vivid imagery and figurative language. The author uses words like "meandered," "sleek," "sinuous," "full-bodied," "chasing," "gurgle," "laugh," "glints," "gleams," and "sparkles" to create a rich and engaging picture of the river. The text also employs repetition, with words like "chatter" and "bubble" appearing multiple times, which adds to the overall rhythm and flow of the passage. However, some of the language used is complex, such as "entranced," "fascinated," and "spell-bound," which may make it more difficult for some readers to follow. Overall, the text is well-written and enjoyable to read, but may pose a challenge for some readers due to its complexity.
# SCORE:  80
# EXPLANATION:  This text has a relatively high readability score due to its use of vivid imagery and figurative language. The author uses words like "meandered," "sleek," "sinuous," "full-bodied," "chasing," "gurgle," "laugh," "glints," "gleams," and "sparkles" to create a rich and engaging picture of the river. The text also employs repetition, with words like "chatter" and "bubble" appearing multiple times, which adds to the overall rhythm and flow of the passage. However, some of the language used is complex, such as "entranced," "fascinated," and "spell-bound," which may make it more difficult for some readers to follow. Overall, the text is well-written and enjoyable to read, but may pose a challenge for some readers due to its complexity.
# Text 4053:
# Score: 60%
# Explanation: This text has a moderate level of readability. It contains some complex vocabulary and sentence structures, such as "truly picnic fashion," "hard breathing within," and "Aunt Lydia's strong, deep voice." However, the overall structure of the text is relatively simple, with short sentences and a clear narrative flow. The text also includes some descriptive language that helps to paint a picture of the scene, such as "south" and "sun stayed on it for many hours." Overall, the text is not overly difficult to read, but it may require some concentration and attention to follow the author's meaning.
# SCORE:  60
# EXPLANATION:  This text has a moderate level of readability. It contains some complex vocabulary and sentence structures, such as "truly picnic fashion," "hard breathing within," and "Aunt Lydia's strong, deep voice." However, the overall structure of the text is relatively simple, with short sentences and a clear narrative flow. The text also includes some descriptive language that helps to paint a picture of the scene, such as "south" and "sun stayed on it for many hours." Overall, the text is not overly difficult to read, but it may require some concentration and attention to follow the author's meaning.
# Text 4054:
# 0% - Very hard to read, requires a lot of concentration and effort to understand the text. 10% - Somewhat hard to read, may require some effort to understand, but still relatively easy. 20% - Moderately hard to read, may require some concentration to understand the text. 30% - Slightly hard to read, may require some effort to understand, but still generally easy. 40% - Neutral, neither easy nor hard to read. 50% - Easy to read, requires minimal effort to understand the text. 60% - Very easy to read, requires little to no effort to understand the text. 70% - Extremely easy to read, requires almost no effort to understand the text. 80% - Nearly effortless to read, requires almost no concentration to understand the text. 90% - Nearly perfect readability, requires minimal concentration to understand the text. 100% - Ideal
# Output format not recognized.
# Text 4055:
# Score: 60%
# Explanation: This text is moderately difficult to read, with a moderate level of complexity in sentence structure and vocabulary. The use of long sentences and descriptive language creates a vivid image of the setting, but may challenge some readers' comprehension.
#
# Score: 80%
# Explanation: This text is relatively easy to read, with a good balance of simple and complex sentence structures. The vocabulary is varied, but not overly challenging, making it accessible to a wide range of readers.
#
# Score: 90%
# Explanation: This text is very easy to read, with simple sentence structures and a limited vocabulary. The text is straightforward and easy to follow, making it an excellent choice for readers of all levels.
#
# Please let me know how you would rate the readability of the text you provided.
# SCORE:  60
# EXPLANATION:  This text is moderately difficult to read, with a moderate level of complexity in sentence structure and vocabulary. The use of long sentences and descriptive language creates a vivid image of the setting, but may challenge some readers' comprehension.
# Text 4056:
# Score: 80%
# Explanation: The text is written in a clear and concise manner, with simple vocabulary and short sentences. The story is easy to follow, and the reader can easily imagine the scenario described. However, some of the sentences are quite long, which may make them difficult to follow for some readers. Overall, the readability of the text is around 80%.
# SCORE:  80
# EXPLANATION:  The text is written in a clear and concise manner, with simple vocabulary and short sentences. The story is easy to follow, and the reader can easily imagine the scenario described. However, some of the sentences are quite long, which may make them difficult to follow for some readers. Overall, the readability of the text is around 80%.
# Text 4057:
# Score: 60%
# Explanation: This text is moderately difficult to read due to the use of complex vocabulary and sentence structures. The language is rich and descriptive, but it may challenge readers who are not familiar with literary devices such as metaphor, simile, and personification. The use of rhetorical questions and hypothetical scenarios also adds to the complexity of the text. However, the overall structure of the passage is clear and easy to follow, making it accessible to readers who are willing to invest time and effort in understanding it.
# SCORE:  60
# EXPLANATION:  This text is moderately difficult to read due to the use of complex vocabulary and sentence structures. The language is rich and descriptive, but it may challenge readers who are not familiar with literary devices such as metaphor, simile, and personification. The use of rhetorical questions and hypothetical scenarios also adds to the complexity of the text. However, the overall structure of the passage is clear and easy to follow, making it accessible to readers who are willing to invest time and effort in understanding it.
# Text 4058:
# For example, "Score: 60%, Explanation: The text is moderately difficult to read, with a few complex sentences and unfamiliar vocabulary."
# Output format not recognized.
# Text 4059:
# For example, "Score: 70%, Explanation: The text is written in a clear and straightforward manner, with simple vocabulary and short sentences, making it easy to read."
#
# Please let me know how you would rate the readability of the given text.
# Output format not recognized.
# Text 4060:
# Score: 60%
# Explanation: The text is written in a clear and straightforward manner, with simple sentence structures and basic vocabulary. However, it may be challenging for some readers, especially those with limited English proficiency, to fully comprehend the text due to the use of complex sentence structures and some technical terms (e.g., "liberal sum"). Additionally, the text contains some cultural references (e.g., "Irish girl") that may be unfamiliar to some readers. Overall, the readability of the text is around 60%.
# SCORE:  60
# EXPLANATION:  The text is written in a clear and straightforward manner, with simple sentence structures and basic vocabulary. However, it may be challenging for some readers, especially those with limited English proficiency, to fully comprehend the text due to the use of complex sentence structures and some technical terms (e.g., "liberal sum"). Additionally, the text contains some cultural references (e.g., "Irish girl") that may be unfamiliar to some readers. Overall, the readability of the text is around 60%.
# Text 4061:
# Score: 60% Explanation: This text is moderately difficult to read, with a vocabulary that is not too challenging but still requires some effort to understand. The sentence structure is relatively complex, with multiple clauses and phrases, which can make it harder to follow. Additionally, some of the words used are old-fashioned or regional, which may be unfamiliar to some readers. However, the text is still relatively easy to read, and the meaning is clear overall.
# Output format not recognized.
# Text 4062:
# 0% - Hard to read, the text is too complex and contains many difficult vocabulary words. 20% - Somewhat easy to read, but the text still contains complex vocabulary and sentence structures. 40% - Easy to read, but may contain some difficult words or phrases. 60% - Very easy to read, with simple vocabulary and sentence structures. 100% - Extremely easy to read, with simple and straightforward language.
# Output format not recognized.
# Text 4063:
# For example: "Score: 80% Explanation: The text is written in a clear and concise manner, with simple vocabulary and short sentences. It is easy to follow and understand, but some of the sentences are a bit long and could be broken up for better readability."
# Output format not recognized.
# Text 4064:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a vocabulary that is not too complex but still requires some effort to understand. The sentences are relatively long and convoluted, which can make them difficult to follow. Additionally, some of the phrases used are idiomatic and may not be immediately familiar to all readers. However, the overall structure of the text is clear and easy to follow, making it still relatively easy to read.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a vocabulary that is not too complex but still requires some effort to understand. The sentences are relatively long and convoluted, which can make them difficult to follow. Additionally, some of the phrases used are idiomatic and may not be immediately familiar to all readers. However, the overall structure of the text is clear and easy to follow, making it still relatively easy to read.
# Text 4065:
# Score: 80%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. The use of descriptive language, such as "rippling silver hair" and "soft blue eyes," adds to the readability of the text. However, some of the sentences are quite long and could be broken up for easier comprehension. Overall, the text is easy to read but could benefit from some minor adjustments for improved readability.
# SCORE:  80
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. The use of descriptive language, such as "rippling silver hair" and "soft blue eyes," adds to the readability of the text. However, some of the sentences are quite long and could be broken up for easier comprehension. Overall, the text is easy to read but could benefit from some minor adjustments for improved readability.
# Text 4066:
# Score: 60%
# Explanation: The text has a moderate level of readability, with a vocabulary that is not too complex but still requires some effort to understand. The sentences are relatively long and contain some subordinate clauses, which can make them harder to follow. Additionally, some of the phrases are quite descriptive and may require additional context to fully comprehend. Overall, the text is still relatively easy to read, but it may pose some challenges for readers who are not used to reading complex sentences or unfamiliar vocabulary.
# SCORE:  60
# EXPLANATION:  The text has a moderate level of readability, with a vocabulary that is not too complex but still requires some effort to understand. The sentences are relatively long and contain some subordinate clauses, which can make them harder to follow. Additionally, some of the phrases are quite descriptive and may require additional context to fully comprehend. Overall, the text is still relatively easy to read, but it may pose some challenges for readers who are not used to reading complex sentences or unfamiliar vocabulary.
# Text 4067:
# For example: "Score: 60%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4068:
# 0% - Hard to read, 100% - Easy to read.
# Output format not recognized.
# Text 4069:
# For example, "Score: 60%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4070:
# Score: 70%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, some of the sentences are quite long and complex, which can make them difficult to follow for some readers. Additionally, the use of technical terms like "pleasure craft" and "nose dip" may be unfamiliar to some readers, which can also affect readability. Overall, the text is easy to read but may require some effort for readers who are not familiar with nautical terminology.
# SCORE:  70
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, some of the sentences are quite long and complex, which can make them difficult to follow for some readers. Additionally, the use of technical terms like "pleasure craft" and "nose dip" may be unfamiliar to some readers, which can also affect readability. Overall, the text is easy to read but may require some effort for readers who are not familiar with nautical terminology.
# Text 4071:
# Score: 60%
# ...
# Text 4695:
# For example, "Score: 80%, Explanation: The text is written at a good level of complexity, with some challenging vocabulary and sentence structures, but overall it is easy to understand."
# Output format not recognized.
# Text 4696:
# Score: 80%
# Explanation: This text is relatively easy to read, with a 7th-grade reading level according to the Flesch-Kincaid readability test. The language used is simple and straightforward, with short sentences and basic vocabulary. However, there are some complex sentences and technical terms, such as "glaciers can too" and "press and grind the land below," which may make it difficult for some readers to fully understand. Overall, the text is well-written and easy to follow, but may require some additional explanation or context for complete comprehension.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a 7th-grade reading level according to the Flesch-Kincaid readability test. The language used is simple and straightforward, with short sentences and basic vocabulary. However, there are some complex sentences and technical terms, such as "glaciers can too" and "press and grind the land below," which may make it difficult for some readers to fully understand. Overall, the text is well-written and easy to follow, but may require some additional explanation or context for complete comprehension.
# Text 4697:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary, making it easy to read."
# Output format not recognized.
# Text 4698:
# Score: 80%
# Explanation: This text is relatively easy to read, with a good mix of short and medium-length sentences. The vocabulary is age-appropriate, and the concepts are explained clearly and simply. However, some of the sentences are a bit long and could be broken up for better readability. Additionally, there are a few complex sentences that may challenge younger readers. Overall, the text is well-written and accessible to a wide range of readers.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a good mix of short and medium-length sentences. The vocabulary is age-appropriate, and the concepts are explained clearly and simply. However, some of the sentences are a bit long and could be broken up for better readability. Additionally, there are a few complex sentences that may challenge younger readers. Overall, the text is well-written and accessible to a wide range of readers.
# Text 4699:
# 0%, very hard to read, 100%, very easy to read.
# Output format not recognized.
# Text 4700:
# 0% - Very hard to read, 100% - Very easy to read.
# Output format not recognized.
# Text 4701:
# Score: 80%
# Explanation: This text is relatively easy to read, with a vocabulary that is mostly familiar to most readers. The sentences are generally short and simple, with a clear structure and flow. However, there are a few complex sentences and technical terms (such as "trapping heat" and "tilted inward") that may challenge some readers. Overall, the text is well-written and accessible, but not quite perfect for a 100% readability score.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a vocabulary that is mostly familiar to most readers. The sentences are generally short and simple, with a clear structure and flow. However, there are a few complex sentences and technical terms (such as "trapping heat" and "tilted inward") that may challenge some readers. Overall, the text is well-written and accessible, but not quite perfect for a 100% readability score.
# Text 4702:
# Score: 60%
# Explanation: The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, the topic is quite complex and may be difficult for some readers to fully comprehend, especially those without prior knowledge of geography or the polar regions.
#
# Score: 80%
# Explanation: The text is well-written and easy to follow, with a clear structure and use of transitions to connect ideas. The author also uses descriptive language to help readers visualize the scene, such as "sheet of ice floating over a cold, deep ocean" and "high, flat plateau." However, some of the vocabulary may be unfamiliar to some readers, such as "polar summer" and "South Pole."
#
# Score: 90%
# Explanation: The text is very easy to read and understand, with short, simple sentences and a clear, logical structure. The author uses concrete details and vivid imagery to help readers visualize the scene, making it easy to picture oneself standing on the North Pole or South
# SCORE:  60
# EXPLANATION:  The text is written in a clear and concise manner, with short sentences and simple vocabulary. However, the topic is quite complex and may be difficult for some readers to fully comprehend, especially those without prior knowledge of geography or the polar regions.
# Text 4703:
# For example, "70%, easy to read" and "The text is written in simple language and has a clear structure, making it easy to follow.". Please let me know how you would rate the readability of the given text.
# Output format not recognized.
# Text 4704:
# For example, "Score: 80%, Explanation: The text is written at a 8th grade reading level, with a vocabulary that is challenging but not impossible to understand."
# Output format not recognized.
# Text 4705:
# For example, "Score: 80%, Explanation: The text is written in a clear and concise manner, with technical terms explained in an accessible way."
# Output format not recognized.
# Text 4706:
# For example:
#
# "Score: 80%
# Explanation: This text is relatively easy to read, with simple vocabulary and short sentences. However, some of the sentences are quite long, which can make them harder to follow. Additionally, some of the technical terms (such as "peristalsis" and "gastric juice") may be unfamiliar to some readers, which can make the text slightly more difficult to read."
#
# Please provide your answer for the given text.
# Output format not recognized.
# Text 4707:
# Score: 60%
# Explanation: The text is written in a clear and concise manner, with technical terms and concepts explained in a way that is easy to understand. However, there are some complex sentences and ideas that may make it difficult for some readers to follow. Overall, the readability of the text is around 60%.
# SCORE:  60
# EXPLANATION:  The text is written in a clear and concise manner, with technical terms and concepts explained in a way that is easy to understand. However, there are some complex sentences and ideas that may make it difficult for some readers to follow. Overall, the readability of the text is around 60%.
# Text 4708:
# Score: 80% Explanation: This text is relatively easy to read, with a 8th-grade reading level according to the Flesch-Kincaid readability test. The language used is simple and straightforward, with short sentences and basic vocabulary. The text also includes some visual aids, such as the instructions for the experiment, which can help readers understand the concepts better. However, there are some complex concepts, such as the idea of absorbing and reflecting energy, that may be difficult for some readers to fully grasp without additional explanation or context. Overall, the text is well-written and accessible to a wide range of readers, but it may still require some effort to fully comprehend the scientific concepts presented.
# Output format not recognized.
# Text 4709:
# 0% - Very hard to read, 100% - Very easy to read.
# Output format not recognized.
# Text 4710:
# For example, "Score: 80%, Explanation: The text is written at a 8th grade level, with complex sentences and technical vocabulary that may be challenging for younger readers."
#
# Score: 60%
# Explanation: The text is written at a moderate level of readability, with a mix of simple and complex sentences. However, some of the technical vocabulary may be challenging for younger readers, such as "Antarctica," "scientist," and "fuel." Additionally, the text includes some long sentences and phrases, which may make it difficult for some readers to follow.
# Output format not recognized.
# Text 4711:
# 0% - Very hard to read, 10% - Hard to read, 20% - Somewhat difficult, 30% - Neutral, 40% - Somewhat easy, 50% - Easy to read, 60% - Very easy to read, 70% - Extremely easy to read, 80% - Nearly perfect to read, 90% - Perfect to read, 100% - Ideal to read.
# Output format not recognized.
# Text 4712:
# Score: 80%
# Explanation: This text is relatively easy to read, with a 7th-grade reading level according to the Flesch-Kincaid readability test. The language used is straightforward and simple, with short sentences and basic vocabulary. However, there are some complex concepts discussed, such as how animals survive in cold climates and how they stay warm, which may require some additional explanation or context for younger readers to fully understand. Overall, the text is well-written and accessible to a wide range of readers, but may benefit from additional support or scaffolding for younger or less experienced readers.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a 7th-grade reading level according to the Flesch-Kincaid readability test. The language used is straightforward and simple, with short sentences and basic vocabulary. However, there are some complex concepts discussed, such as how animals survive in cold climates and how they stay warm, which may require some additional explanation or context for younger readers to fully understand. Overall, the text is well-written and accessible to a wide range of readers, but may benefit from additional support or scaffolding for younger or less experienced readers.
# Text 4713:
# For example, "Score: 80%, Explanation: The text is written in simple language and has a clear structure, making it easy to read."
# Output format not recognized.
# Text 4714:
# For example, "Score: 80%, Explanation: The text is written at a 4th grade reading level, with a vocabulary that is slightly challenging but still accessible to most 4th graders."
# Output format not recognized.
# Text 4715:
# 0% means very hard to read, 100% means very easy to read. 50% means it's average.
#
# Score: 70%
# Explanation: The text is written at a moderate level of difficulty, with some challenging vocabulary and sentence structures. However, the overall meaning is clear and easy to follow, making it accessible to a wide range of readers.
#
# Please provide the actual text you would like me to read, and I will be happy to assist you.
# Output format not recognized.
# Text 4716:
# 0% - Very hard to read, 10% - Hard to read, 20% - Somewhat difficult, 30% - Easy to read, 40% - Very easy to read, 50% - Extremely easy to read, 60% - Nearly perfect, 70% - Perfectly readable, 80% - Almost too easy to read, 90% - Very easy to understand, 100% - Easy to understand.
# Output format not recognized.
# Text 4717:
# Score: 80%
# Explanation: This text is relatively easy to read, with a moderate level of complexity. The language used is straightforward and simple, with short sentences and basic vocabulary. However, there are some technical terms such as "molecules" and "atoms" that may be unfamiliar to some readers, which could make it more difficult to understand for a small percentage of readers. Overall, the text is well-structured and easy to follow, making it accessible to a wide range of readers.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a moderate level of complexity. The language used is straightforward and simple, with short sentences and basic vocabulary. However, there are some technical terms such as "molecules" and "atoms" that may be unfamiliar to some readers, which could make it more difficult to understand for a small percentage of readers. Overall, the text is well-structured and easy to follow, making it accessible to a wide range of readers.
# Text 4718:
# Score: 80%
# Explanation: This text is relatively easy to read, with a good balance of simple language and complex ideas. The author uses clear and concise sentences, and the text is well-organized with a clear structure. However, there are a few places where the language could be more precise, and some of the scientific terms could be explained in more detail for readers who may not be familiar with them. Overall, the text is well-written and accessible to a wide range of readers.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a good balance of simple language and complex ideas. The author uses clear and concise sentences, and the text is well-organized with a clear structure. However, there are a few places where the language could be more precise, and some of the scientific terms could be explained in more detail for readers who may not be familiar with them. Overall, the text is well-written and accessible to a wide range of readers.
# Text 4719:
# For example, "Score: 80%, Explanation: The text is written at a 8th grade reading level, with a vocabulary that is challenging but not impossible to understand."
# Output format not recognized.
# Text 4720:
# 0% - Hard to read
#
# * The text is very complex and contains many technical terms that may be unfamiliar to most readers.
# * The sentence structure is also quite difficult, with many long and complicated sentences that can be challenging to follow.
#
# 10% - Somewhat easy to read
#
# * The text contains some basic vocabulary and sentence structures that are easy to understand.
# * However, the complexity of the text still makes it difficult for some readers to fully comprehend.
#
# 20% - Easy to read
#
# * The text contains mostly basic vocabulary and sentence structures, making it easier for readers to understand.
# * However, the text may still be a bit challenging for some readers, especially those who are not familiar with the subject matter.
#
# 30% - Very easy to read
#
# * The
# Output format not recognized.
# Text 4721:
# For example, "Score: 80%, Explanation: The text is written in clear and concise language, with short sentences and simple vocabulary, making it easy to read."
#
# Please rate the readability of the text you provided.
# Output format not recognized.
# Text 4722:
# Score: 80%
# Explanation: This text is relatively easy to read, with a moderate level of complexity. The vocabulary is mostly basic and the sentences are straightforward, making it accessible to a wide range of readers. However, there are some technical terms used in the context of geometry, such as "coplanar", "colinear", "polyhedron", and "volume", which may require some additional effort to understand. Overall, the text is well-structured and easy to follow, but may benefit from some additional explanations or examples to help readers fully grasp the concepts being discussed.
# SCORE:  80
# EXPLANATION:  This text is relatively easy to read, with a moderate level of complexity. The vocabulary is mostly basic and the sentences are straightforward, making it accessible to a wide range of readers. However, there are some technical terms used in the context of geometry, such as "coplanar", "colinear", "polyhedron", and "volume", which may require some additional effort to understand. Overall, the text is well-structured and easy to follow, but may benefit from some additional explanations or examples to help readers fully grasp the concepts being discussed.
# Text 4723:
# 0% - Hard to read
# 10% - Some words are hard to understand
# 20% - Some sentences are hard to follow
# 30% - Most words are recognizable, but some are hard to read
# 40% - Easy to read, but some vocabulary may be challenging
# 50% - Very easy to read, with minimal challenging vocabulary
# 60% - Extremely easy to read, with minimal difficulty understanding complex sentences
# 70% - Almost too easy to read, with only a few words or phrases causing difficulty
# 80% - Very easy to read, with a few complex sentences that may require some thought
# 90% - Easy to read, with only a few challenging words or phrases
# 100% - Extremely easy to read, with no challenging vocabulary or complex sentences.
# Output format not recognized.

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# %%
download_file('/kaggle/working/TextReadabilityAnnotation/project-files/llm-data/llm-results/CLEAR_Corpus_6.01_LLM-output.csv', 'out')
